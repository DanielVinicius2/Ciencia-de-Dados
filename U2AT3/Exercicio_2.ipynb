# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("archit9406/customer-transaction-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'customer-transaction-dataset' dataset.
# Path to dataset files: /kaggle/input/customer-transaction-dataset

# %%
df = pd.read_excel("/kaggle/input/customer-transaction-dataset/KPMG_VI_New_raw_data_update_final.xlsx", sheet_name="Transactions")


print("Dataset carregado com sucesso!")
print("Total de registros:", len(df))
df.head()
# Out:
# Dataset carregado com sucesso!
# Total de registros: 20001
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                     transaction_id
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Unnamed: 1   Unnamed: 2           Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0  product_id  customer_id     transaction_date  online_order  order_status
# 1           2         2950  2017-02-25 00:00:00         False      Approved
# 2           3         3120  2017-05-21 00:00:00          True      Approved
# 3          37          402  2017-10-16 00:00:00         False      Approved
# 4          88         3135  2017-08-31 00:00:00         False      Approved
#
# ...

# %%
exact_duplicates = df.duplicated().sum()

print(f"\nNúmero de duplicatas EXATAS encontradas: {exact_duplicates}")

# Remover duplicatas exatas
df_no_exact = df.drop_duplicates()

print("Após remover duplicatas exatas:", len(df_no_exact))
# Out:
# Número de duplicatas EXATAS encontradas: 0
# Após remover duplicatas exatas: 20001

# %%
if "transaction_date" in df_temp.columns:
    df_temp_sorted = df_temp.sort_values("transaction_date")
else:
    df_temp_sorted = df_temp.copy()  # fallback caso falta a coluna

df_resolved = df_temp_sorted.drop_duplicates(subset=["duplicate_group"], keep="last")

print("\nAgrupamentos aproximados criados:", group_id)
print("Total REMOVIDO por duplicatas aproximadas:", len(df_temp) - len(df_resolved))
print("Total final de registros limpos:", len(df_resolved))
# Out:
# Agrupamentos aproximados criados: 0
# Total REMOVIDO por duplicatas aproximadas: 19999
# Total final de registros limpos: 2

# %%
print("\n--------- RESUMO FINAL ---------\n")
print("Registros originais:", len(df))
print("Após remover duplicatas EXATAS:", len(df_no_exact))
print("Após resolver duplicatas APROXIMADAS:", len(df_resolved))
print("\nRedução total:", len(df) - len(df_resolved))
# Out:
# --------- RESUMO FINAL ---------
#
# Registros originais: 20001
# Após remover duplicatas EXATAS: 20001
# Após resolver duplicatas APROXIMADAS: 2
#
# Redução total: 19999
